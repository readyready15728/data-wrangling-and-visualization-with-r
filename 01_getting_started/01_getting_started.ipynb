# %% [markdown]
# Chapter 1 covers very basic stuff with RStudio which I will not be using here. However, it is important to install packages `tidyverse` and `dslabs`. That is better done in an ordinary R console instead of here, so that all diagnostic output can be seen.
